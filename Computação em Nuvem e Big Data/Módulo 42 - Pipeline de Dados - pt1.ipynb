# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Solução do item 1.6.

# %%
# O token é informação sigilosa e muito importante, para isso utilizarei o recurso GetPass.

from getpass import getpass

token = getpass()
# Out:
# ··········

# %%
# Interagir com os dados semi-estruturados na web.
import json

import requests

base_url = f'https://api.telegram.org/bot{token}'

# %%
# Retornando as informações do bot.
response = requests.get(url=f'{base_url}/getMe')
print(f'{base_url}/getMe')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# https://api.telegram.org/bot7792124067:AAFqKUGbPML_mYhW1o_gvs3R_Ilk85vL-RA/getMe
# {
#   "ok": true,
#   "result": {
#     "id": 7792124067,
#     "is_bot": true,
#     "first_name": "pipeline-listener",
#     "username": "m34pipelinebot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false,
#     "can_connect_to_business": false,
#     "has_main_web_app": false
#   }
# }

# %%
# Retornando as mensagens captadas pelo bot.
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 518697174,
#       "message": {
#         "message_id": 3,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750636738,
#         "text": "Ol\u00e1, mundo!"
#       }
#     },
#     {
#       "update_id": 518697175,
#       "message": {
#         "message_id": 4,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637650,
#         "text": "Ouviram"
#       }
#     },
#     {
#       "update_id": 518697176,
#       "message": {
#         "message_id": 5,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637652,
#         "text": "Do"
#       }
#     },
#     {
#       "update_id": 518697177,
#       "message": {
#         "message_id": 6,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637653,
#         "text": "Ipiranga"
#       }
#     },
#     {
#       "update_id": 518697178,
#       "message": {
#         "message_id": 7,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637657,
#         "text": "\u00c0s"
#       }
#     },
#     {
#       "update_id": 518697179,
#       "message": {
#         "message_id": 8,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637659,
#         "text": "Margens"
#       }
#     },
#     {
#       "update_id": 518697180,
#       "message": {
#         "message_id": 9,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637662,
#         "text": "Pl\u00e1cidas"
#       }
#     },
#     {
#       "update_id": 518697181,
#       "message": {
#         "message_id": 10,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637664,
#         "text": "De"
#       }
#     },
#     {
#       "update_id": 518697182,
#       "message": {
#         "message_id": 11,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637675,
#         "text": "Um povo her\u00f3ico, o brado retumbante"
#       }
#     },
#     {
#       "update_id": 518697183,
#       "message": {
#         "message_id": 12,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637679,
#         "text": "\u2764\ufe0f"
#       }
#     },
#     {
#       "update_id": 518697184,
#       "message": {
#         "message_id": 13,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637689,
#         "photo": [
#           {
#             "file_id": "AgACAgEAAyEFAASlkz-gAAMNaFiceYB237HbTh7VTq3K7pDgSOgAAuCuMRsCvchGgkR5OMdDGooBAAMCAANzAAM2BA",
#             "file_unique_id": "AQAD4K4xGwK9yEZ4",
#             "file_size": 1061,
#             "width": 90,
#             "height": 49
#           },
#           {
#             "file_id": "AgACAgEAAyEFAASlkz-gAAMNaFiceYB237HbTh7VTq3K7pDgSOgAAuCuMRsCvchGgkR5OMdDGooBAAMCAANtAAM2BA",
#             "file_unique_id": "AQAD4K4xGwK9yEZy",
#             "file_size": 15796,
#             "width": 320,
#             "height": 174
#           },
#           {
#             "file_id": "AgACAgEAAyEFAASlkz-gAAMNaFiceYB237HbTh7VTq3K7pDgSOgAAuCuMRsCvchGgkR5OMdDGooBAAMCAAN4AAM2BA",
#             "file_unique_id": "AQAD4K4xGwK9yEZ9",
#             "file_size": 38011,
#             "width": 612,
#             "height": 332
#           }
#         ]
#       }
#     },
#     {
#       "update_id": 518697185,
#       "message": {
#         "message_id": 14,
#         "from": {
#           "id": 5908888919,
#           "is_bot": false,
#           "first_name": "KAIO",
#           "last_name": "OLIVEIRA",
#           "username": "eu_kaio_oliveira",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002777890720,
#           "title": "Grupo - Pipeline de Dados - Jun 2025",
#           "type": "supergroup"
#         },
#         "date": 1750637700,
#         "voice": {
#           "duration": 5,
#           "mime_type": "audio/ogg",
#           "file_id": "AwACAgEAAyEFAASlkz-gAAMOaFichHFJTqB7TuqcOQXn1gr96u8AAnMFAAICvchGr1h4xJvQVzo2BA",
#           "file_unique_id": "AgADcwUAAgK9yEY",
#           "file_size": 35696
#         }
#       }
#     }
#   ]
# }
