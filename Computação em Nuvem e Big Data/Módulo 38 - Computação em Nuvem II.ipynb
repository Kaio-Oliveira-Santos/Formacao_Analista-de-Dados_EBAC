# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>AWS Lambda;</li>
#   <li>AWS Step Functions;</li>
#   <li>AWS EventBridge.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. AWS Lambda

# %% [markdown]
# Replique as atividades do item 1.3 em sua conta.

# %% [markdown]
# 1. AWS Lambda para bucket bronze:

# %% [markdown]
# ```python
# import json
# import logging
# from datetime import datetime
#
# import boto3
# import urllib3
# from botocore.exceptions import ClientError
#
#
# def lambda_handler(event, context) -> bool:
#
#   # -- setup
#
#   URL = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.4392/dados?formato=json'
#   BRONZE_BUCKET = 'modulo-39-ebac-bronze-kaio'
#
#   client = boto3.client('s3')
#
#   date = datetime.now().strftime('%Y-%m-%d')
#   filename_json = f'stock-exchange-{date}.json'
#
#   # -- extract
#
#   try:
#     http = urllib3.PoolManager()
#     response = http.request(url=URL, method='get')
#   except Exception as exc:
#     raise exc
#   else:
#     data = json.loads(response.data.decode())
#     logging.info(msg=data)
#
#   # -- transform
#
#   ...
#
#   # -- load
#
#   try:
#       with open(f'/tmp/{filename_json}', mode='w', encoding='utf8') as fp:
#           json.dump(data, fp)
#       client.upload_file(Filename=f'/tmp/{filename_json}', Bucket=BRONZE_BUCKET, Key=filename_json)
#   except ClientError as exc:
#       raise exc
#
#   return json.dumps(dict(status=True))
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. AWS Lambda para bucket silver:

# %% [markdown]
# ```python
# import json
# from datetime import datetime
#
# import boto3
# from botocore.exceptions import ClientError
#
#
# def lambda_handler(event, context) -> bool:
#     # -- setup
#     BRONZE_BUCKET = 'modulo-39-ebac-bronze-kaio'
#     SILVER_BUCKET = 'modulo-39-ebac-silver-kaio'
#
#     client = boto3.client('s3')
#
#     date = datetime.now().strftime('%Y-%m-%d')
#     filename_csv = f'stock-exchange-{date}.csv'
#     filename_json = f'stock-exchange-{date}.json'
#
#     # -- extract
#     client.download_file(BRONZE_BUCKET, filename_json, f'/tmp/{filename_json}')
#
#     with open(f"/tmp/{filename_json}", mode='r', encoding='utf8') as fp:
#         data = json.load(fp)
#
#     # -- transform
#     transformed_data = []
#
#     for record in data:
#         transformed_record = {
#             'taxa': record['valor'].replace(',', '.'),
#             'dataTaxa': datetime.strptime(record['data'], '%d/%m/%Y').strftime('%Y-%m-%d'),
#         }
#         transformed_data.append(transformed_record)
#
#     # -- load
#     try:
#         with open(f'/tmp/{filename_csv}', mode='w', encoding='utf8') as fp:
#             fp.write('taxa,dataTaxa\n')
#             for record in transformed_data:
#                 fp.write(f"{record['taxa']},{record['dataTaxa']}\n")
#         client.upload_file(Filename=f'/tmp/{filename_csv}', Bucket=SILVER_BUCKET, Key=f'data_referencia={date}/{filename_csv}')
#     except ClientError as exc:
#         raise exc
#
#     return json.dumps(dict(status=True))
#
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. AWS Lambda para tabela:

# %% [markdown]
# ```python
# import json
# from datetime import datetime
#
# import boto3
# from botocore.exceptions import ClientError
#
#
# def lambda_handler(event, context) -> bool:
#
#   # -- setup
#
#   SILVER_BUCKET = 'modulo-39-ebac-silver-kaio'
#
#   query = f"""
#   CREATE EXTERNAL TABLE IF NOT EXISTS cdi (
#     taxa double,
#     dataTaxa string
#   )
#   PARTITIONED BY (
#     data_referencia string
#   )
#   ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
#   WITH SERDEPROPERTIES ('separatorChar'=',')
#   LOCATION 's3://{SILVER_BUCKET}/'
#   """
#
#   client = boto3.client('athena')
#
#   # -- create
#
#   try:
#     client.start_query_execution(
#       QueryString=query,
#       ResultConfiguration={'OutputLocation': 's3://modulo8-kaio-ebac/'}
#     )
#   except ClientError as exc:
#     raise exc
#
#   # -- update
#
#   try:
#     client.start_query_execution(
#       QueryString='MSCK REPAIR TABLE cdi',
#       ResultConfiguration={'OutputLocation': 's3://modulo8-kaio-ebac/'}
#     )
#   except ClientError as exc:
#     raise exc
#
#   return json.dumps(dict(status=True))
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2\. AWS Step Functions

# %% [markdown]
# Replique as atividades do item 2.3 em sua conta.

# %%
Criar uma state machine com três tasks, uma com cada função lambda criada na item 1.3.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3\. AWS EventBridge

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %% [markdown]
# Criar um evento que inicie a state machine do item 2.3.

# %% [markdown]
# O material do curso está desatualizado. Agora, existe uma nova mecânica no EventBrigde.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
